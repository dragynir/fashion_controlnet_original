# %%
import pandas as pd

df = pd.read_csv('../training/iMaterialist(Fashion)/caption.csv')
df
# Out:
#                                        fast_clip_prompts  \
# 0      a man in a suit posing for a picture, erwin ol...
# 1      a tank top hanging on a hanger on a wall, crea...
# 2      a woman in a dress on a red carpet, christina ...
# 3      a woman in a wedding dress posing for a pictur...
# 4      a woman in a purple dress posing for a picture...
# ...                                                  ...
# 45190  a woman standing in front of a wall of succule...
# 45191  a woman in a red shirt and black pants, long h...
# 45192  a woman standing in front of a large window, w...
# 45193  a man in a suit standing on a red carpet, navy...
# 45194  a woman in a black dress posing for a picture,...
#
#                                     ImageId
# 0      00000663ed1ff0c4e0132b9b9ac53f6e.jpg
# 1      0000fe7c9191fba733c8a69cfaf962b7.jpg
# 2      0002ec21ddb8477e98b2cbb87ea2e269.jpg
# 3      0002f5a0ebc162ecfb73e2c91e3b8f62.jpg
# 4      0004467156e47b0eb6de4aa6479cbd15.jpg
# ...                                     ...
# 45190  fff8d9bd5ad4354b66355dd797942b42.jpg
# 45191  fffb65463df408e308983ef743b77491.jpg
# 45192  fffc631acce2e28e1628de685d40c980.jpg
# 45193  fffe20b555b98c3c1f26c8dfff275cbc.jpg
# 45194  ffffbf7014a9e408bfbb81a75bc70638.jpg
#
# [45195 rows x 2 columns]

# %%
df['len'] = df.fast_clip_prompts.apply(len)
df.len.min(), df.len.max()
# Out:
# (138, 506)

# %%
df.len.hist()
# Out:
# <Axes: >

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from tqdm import tqdm


text = " ".join(df['fast_clip_prompts'].values.tolist())

wordcloud = WordCloud(max_font_size=50, width=600, height=300, background_color='white').generate(text)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.title("label_description_attributes in the images", fontsize=15)
plt.axis("off")
plt.show()
